# %%
import os
import mne
import numpy as np
from fooof import FOOOFGroup
from fooof.data import FOOOFSettings
# Out:
# C:\Users\Christian\AppData\Local\Temp\ipykernel_16980\725504202.py:5: DeprecationWarning:
# The `fooof` package is being deprecated and replaced by the `specparam` (spectral parameterization) package.
# This version of `fooof` (1.1) is fully functional, but will not be further updated.
# New projects are recommended to update to using `specparam` (see Changelog for details).
#   from fooof import FOOOFGroup

# %%
## Subjects and Sessions to include
EEG_INFO = {
    'SUBJ_NUMS': ['10002', '10003', '10004', '10008', '10011', '10012', '10016', '10019', 
                  '10021', '10022', '10023', '10024', '10028', '10031', '10032', '10034', 
                  '10036', '10037', '10039', '10040', '10046', '10048', '10056', '10058'],
    
    'SESS_NUMS' : ['W00', 'W00_2', 'W00_3', 'W00_4',
                    'W08', 'W08_2', 'W08_3', 'W08_4',
                    'W12', 'W12_2', 'W12_3', 'W12_4',
                    'W20', 'W20_2', 'W20_3', 'W20_4'],
}
SUBJ_NUMS = EEG_INFO['SUBJ_NUMS']
SESS_NUMS = EEG_INFO['SESS_NUMS']

# %%
## Directory paths
epoch_load_path = '02_Epoch_EEG/Concatenated'
fooof_save_path = '03_FOOOF_EEG/Concatenated'

# %%
###############################################################################
# Specparam settings (FOOOF - Fitting Oscillations & One Over F)
###############################################################################

# Define the frequency range for fitting
FIT_RANGE = (.5, 13)  # Fit the model from 0.5 Hz to 13 Hz

# Configure FOOOF settings
FOOOF_SETTINGS = FOOOFSettings(
    peak_width_limits=[1, 12],  # Minimum and maximum width of peaks (in Hz)
    max_n_peaks=6,              # Maximum number of peaks to fit
    min_peak_height=0,          # Minimum height of peaks to consider
    peak_threshold=2,           # Threshold for detecting peaks, in standard deviations
    aperiodic_mode='fixed',     # Use fixed aperiodic component
)

# %%
## Loop through each session file
for sub_ind, sub in enumerate(SUBJ_NUMS):  # For each subject
    for sess_ind, sess in enumerate(SESS_NUMS):  # For each session
        
        ###############################################################################
        # Compute PSD (Power Spectral Density)
        ###############################################################################
        
        # Construct file name and path
        full_sess_name = str(sub) + "_" + str(sess)
        subj_fname = full_sess_name + "_epo.fif"
        full_path = os.path.join(epoch_load_path, subj_fname)
        print(full_path)

        # Check if file exists
        if not os.path.exists(full_path):
            print('Current Subject ' + str(sub) + '_' + str(sess) + ' does not exist')
            continue

        # Load epoch .fif file
        epoch = mne.read_epochs(epoch_load_path + '/' + full_sess_name + '_epo.fif', preload=False)

        ## PSD Settings
        FS = epoch.info['sfreq']  # Sampling frequency of signals
        PSD_SETTINGS = {
            'method': 'welch',        # Use Welch's method for PSD estimation
            'window': 'hamm',         # Use Hamming window
            'average': 'median',      # Use median for averaging
            'fmin': .1,               # Minimum frequency of interest (Hz)
            'fmax': 50.,              # Maximum frequency of interest (Hz)
            'n_fft': 1024,            # Number of points in FFT
            'n_overlap': int(FS*0.5), # 50% overlap between segments
            'n_per_seg': int(FS),     # Number of points per segment (1 second)
        }
        
        # Compute Power Spectral Density
        epoch_psd = epoch.compute_psd(**PSD_SETTINGS)
        
        # Reshape into [n_spectra, n_freqs]
        epoch_psd_reshaped = np.squeeze(epoch_psd._data[0, :, :])
        
        ###############################################################################
        # Compute Specparam (using FOOOF - Fitting Oscillations & One Over F)
        ###############################################################################
        # Initialize FOOOFGroup to use for fitting
        fg = FOOOFGroup(*FOOOF_SETTINGS, verbose=False)

        # Fit a group of power spectra with the .fit() method
        fg.fit(epoch_psd.freqs, epoch_psd_reshaped, FIT_RANGE)
        
        # Save model fit results
        fg.save(file_name=str(sub) + '_' + str(sess) + '_fooof_results_fixed',
                file_path=fooof_save_path,
                save_results=True, save_settings=True, save_data=True)
# Out:
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10002_W00_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10002_W00_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...   30004.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 15003 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10002_W00_2_epo.fif
# Current Subject 10002_W00_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10002_W00_3_epo.fif
# Current Subject 10002_W00_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10002_W00_4_epo.fif
# Current Subject 10002_W00_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10002_W08_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10002_W08_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  140026.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 70014 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10002_W08_2_epo.fif
# Current Subject 10002_W08_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10002_W08_3_epo.fif
# Current Subject 10002_W08_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10002_W08_4_epo.fif
# Current Subject 10002_W08_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10002_W12_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10002_W12_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...   20002.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 10002 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10002_W12_2_epo.fif
# Current Subject 10002_W12_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10002_W12_3_epo.fif
# Current Subject 10002_W12_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10002_W12_4_epo.fif
# Current Subject 10002_W12_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10002_W20_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10002_W20_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  170032.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 85017 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10002_W20_2_epo.fif
# Current Subject 10002_W20_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10002_W20_3_epo.fif
# Current Subject 10002_W20_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10002_W20_4_epo.fif
# Current Subject 10002_W20_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10003_W00_epo.fif
# Current Subject 10003_W00 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10003_W00_2_epo.fif
# Current Subject 10003_W00_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10003_W00_3_epo.fif
# Current Subject 10003_W00_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10003_W00_4_epo.fif
# Current Subject 10003_W00_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10003_W08_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10003_W08_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...   60010.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 30006 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10003_W08_2_epo.fif
# Current Subject 10003_W08_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10003_W08_3_epo.fif
# Current Subject 10003_W08_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10003_W08_4_epo.fif
# Current Subject 10003_W08_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10003_W12_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10003_W12_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  160030.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 80016 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10003_W12_2_epo.fif
# Current Subject 10003_W12_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10003_W12_3_epo.fif
# Current Subject 10003_W12_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10003_W12_4_epo.fif
# Current Subject 10003_W12_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10003_W20_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10003_W20_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...   30004.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 15003 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10003_W20_2_epo.fif
# Current Subject 10003_W20_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10003_W20_3_epo.fif
# Current Subject 10003_W20_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10003_W20_4_epo.fif
# Current Subject 10003_W20_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10004_W00_epo.fif
# Current Subject 10004_W00 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10004_W00_2_epo.fif
# Current Subject 10004_W00_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10004_W00_3_epo.fif
# Current Subject 10004_W00_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10004_W00_4_epo.fif
# Current Subject 10004_W00_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10004_W08_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10004_W08_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  800158.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 400080 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10004_W08_2_epo.fif
# Current Subject 10004_W08_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10004_W08_3_epo.fif
# Current Subject 10004_W08_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10004_W08_4_epo.fif
# Current Subject 10004_W08_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10004_W12_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10004_W12_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  740146.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 370074 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10004_W12_2_epo.fif
# Current Subject 10004_W12_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10004_W12_3_epo.fif
# Current Subject 10004_W12_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10004_W12_4_epo.fif
# Current Subject 10004_W12_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10004_W20_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10004_W20_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  510100.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 255051 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10004_W20_2_epo.fif
# Current Subject 10004_W20_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10004_W20_3_epo.fif
# Current Subject 10004_W20_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10004_W20_4_epo.fif
# Current Subject 10004_W20_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10005_W00_epo.fif
# Current Subject 10005_W00 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10005_W00_2_epo.fif
# Current Subject 10005_W00_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10005_W00_3_epo.fif
# Current Subject 10005_W00_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10005_W00_4_epo.fif
# Current Subject 10005_W00_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10005_W08_epo.fif
# Current Subject 10005_W08 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10005_W08_2_epo.fif
# Current Subject 10005_W08_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10005_W08_3_epo.fif
# Current Subject 10005_W08_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10005_W08_4_epo.fif
# Current Subject 10005_W08_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10005_W12_epo.fif
# Current Subject 10005_W12 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10005_W12_2_epo.fif
# Current Subject 10005_W12_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10005_W12_3_epo.fif
# Current Subject 10005_W12_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10005_W12_4_epo.fif
# Current Subject 10005_W12_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10005_W20_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10005_W20_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  100018.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 50010 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10005_W20_2_epo.fif
# Current Subject 10005_W20_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10005_W20_3_epo.fif
# Current Subject 10005_W20_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10005_W20_4_epo.fif
# Current Subject 10005_W20_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10008_W00_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10008_W00_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  280054.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 140028 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10008_W00_2_epo.fif
# Current Subject 10008_W00_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10008_W00_3_epo.fif
# Current Subject 10008_W00_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10008_W00_4_epo.fif
# Current Subject 10008_W00_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10008_W08_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10008_W08_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  120022.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 60012 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10008_W08_2_epo.fif
# Current Subject 10008_W08_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10008_W08_3_epo.fif
# Current Subject 10008_W08_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10008_W08_4_epo.fif
# Current Subject 10008_W08_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10008_W12_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10008_W12_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  600118.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 300060 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10008_W12_2_epo.fif
# Current Subject 10008_W12_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10008_W12_3_epo.fif
# Current Subject 10008_W12_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10008_W12_4_epo.fif
# Current Subject 10008_W12_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10008_W20_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10008_W20_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...   40006.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 20004 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10008_W20_2_epo.fif
# Current Subject 10008_W20_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10008_W20_3_epo.fif
# Current Subject 10008_W20_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10008_W20_4_epo.fif
# Current Subject 10008_W20_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10010_W00_epo.fif
# Current Subject 10010_W00 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10010_W00_2_epo.fif
# Current Subject 10010_W00_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10010_W00_3_epo.fif
# Current Subject 10010_W00_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10010_W00_4_epo.fif
# Current Subject 10010_W00_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10010_W08_epo.fif
# Current Subject 10010_W08 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10010_W08_2_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10010_W08_2_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...   20002.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 10002 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10010_W08_3_epo.fif
# Current Subject 10010_W08_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10010_W08_4_epo.fif
# Current Subject 10010_W08_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10010_W12_epo.fif
# Current Subject 10010_W12 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10010_W12_2_epo.fif
# Current Subject 10010_W12_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10010_W12_3_epo.fif
# Current Subject 10010_W12_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10010_W12_4_epo.fif
# Current Subject 10010_W12_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10010_W20_epo.fif
# Current Subject 10010_W20 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10010_W20_2_epo.fif
# Current Subject 10010_W20_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10010_W20_3_epo.fif
# Current Subject 10010_W20_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10010_W20_4_epo.fif
# Current Subject 10010_W20_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10011_W00_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10011_W00_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...   30004.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 15003 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10011_W00_2_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10011_W00_2_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...   80014.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 40008 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10011_W00_3_epo.fif
# Current Subject 10011_W00_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10011_W00_4_epo.fif
# Current Subject 10011_W00_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10011_W08_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10011_W08_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  310060.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 155031 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10011_W08_2_epo.fif
# Current Subject 10011_W08_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10011_W08_3_epo.fif
# Current Subject 10011_W08_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10011_W08_4_epo.fif
# Current Subject 10011_W08_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10011_W12_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10011_W12_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  280054.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 140028 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10011_W12_2_epo.fif
# Current Subject 10011_W12_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10011_W12_3_epo.fif
# Current Subject 10011_W12_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10011_W12_4_epo.fif
# Current Subject 10011_W12_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10011_W20_epo.fif
# Current Subject 10011_W20 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10011_W20_2_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10011_W20_2_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...   40006.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 20004 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10011_W20_3_epo.fif
# Current Subject 10011_W20_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10011_W20_4_epo.fif
# Current Subject 10011_W20_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10012_W00_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10012_W00_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  530104.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 265053 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10012_W00_2_epo.fif
# Current Subject 10012_W00_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10012_W00_3_epo.fif
# Current Subject 10012_W00_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10012_W00_4_epo.fif
# Current Subject 10012_W00_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10012_W08_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10012_W08_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  520102.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 260052 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10012_W08_2_epo.fif
# Current Subject 10012_W08_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10012_W08_3_epo.fif
# Current Subject 10012_W08_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10012_W08_4_epo.fif
# Current Subject 10012_W08_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10012_W12_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10012_W12_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...   60010.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 30006 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10012_W12_2_epo.fif
# Current Subject 10012_W12_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10012_W12_3_epo.fif
# Current Subject 10012_W12_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10012_W12_4_epo.fif
# Current Subject 10012_W12_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10012_W20_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10012_W20_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...   70012.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 35007 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10012_W20_2_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10012_W20_2_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  200038.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 100020 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10012_W20_3_epo.fif
# Current Subject 10012_W20_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10012_W20_4_epo.fif
# Current Subject 10012_W20_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10016_W00_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10016_W00_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  430084.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 215043 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10016_W00_2_epo.fif
# Current Subject 10016_W00_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10016_W00_3_epo.fif
# Current Subject 10016_W00_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10016_W00_4_epo.fif
# Current Subject 10016_W00_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10016_W08_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10016_W08_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  860170.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 430086 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10016_W08_2_epo.fif
# Current Subject 10016_W08_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10016_W08_3_epo.fif
# Current Subject 10016_W08_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10016_W08_4_epo.fif
# Current Subject 10016_W08_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10016_W12_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10016_W12_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  260050.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 130026 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10016_W12_2_epo.fif
# Current Subject 10016_W12_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10016_W12_3_epo.fif
# Current Subject 10016_W12_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10016_W12_4_epo.fif
# Current Subject 10016_W12_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10016_W20_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10016_W20_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  560110.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 280056 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10016_W20_2_epo.fif
# Current Subject 10016_W20_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10016_W20_3_epo.fif
# Current Subject 10016_W20_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10016_W20_4_epo.fif
# Current Subject 10016_W20_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10017_W00_epo.fif
# Current Subject 10017_W00 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10017_W00_2_epo.fif
# Current Subject 10017_W00_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10017_W00_3_epo.fif
# Current Subject 10017_W00_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10017_W00_4_epo.fif
# Current Subject 10017_W00_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10017_W08_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10017_W08_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  110020.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 55011 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10017_W08_2_epo.fif
# Current Subject 10017_W08_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10017_W08_3_epo.fif
# Current Subject 10017_W08_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10017_W08_4_epo.fif
# Current Subject 10017_W08_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10017_W12_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10017_W12_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...   20002.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 10002 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10017_W12_2_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10017_W12_2_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...   50008.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 25005 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10017_W12_3_epo.fif
# Current Subject 10017_W12_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10017_W12_4_epo.fif
# Current Subject 10017_W12_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10017_W20_epo.fif
# Current Subject 10017_W20 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10017_W20_2_epo.fif
# Current Subject 10017_W20_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10017_W20_3_epo.fif
# Current Subject 10017_W20_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10017_W20_4_epo.fif
# Current Subject 10017_W20_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10019_W00_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10019_W00_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...   90016.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 45009 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10019_W00_2_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10019_W00_2_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  280054.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 140028 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10019_W00_3_epo.fif
# Current Subject 10019_W00_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10019_W00_4_epo.fif
# Current Subject 10019_W00_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10019_W08_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10019_W08_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...   60010.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 30006 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10019_W08_2_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10019_W08_2_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  400078.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 200040 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10019_W08_3_epo.fif
# Current Subject 10019_W08_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10019_W08_4_epo.fif
# Current Subject 10019_W08_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10019_W12_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10019_W12_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  330064.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 165033 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10019_W12_2_epo.fif
# Current Subject 10019_W12_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10019_W12_3_epo.fif
# Current Subject 10019_W12_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10019_W12_4_epo.fif
# Current Subject 10019_W12_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10019_W20_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10019_W20_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  160030.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 80016 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10019_W20_2_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10019_W20_2_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  300058.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 150030 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10019_W20_3_epo.fif
# Current Subject 10019_W20_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10019_W20_4_epo.fif
# Current Subject 10019_W20_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10021_W00_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10021_W00_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...   30004.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 15003 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10021_W00_2_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10021_W00_2_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...   60010.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 30006 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10021_W00_3_epo.fif
# Current Subject 10021_W00_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10021_W00_4_epo.fif
# Current Subject 10021_W00_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10021_W08_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10021_W08_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...   70012.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 35007 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10021_W08_2_epo.fif
# Current Subject 10021_W08_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10021_W08_3_epo.fif
# Current Subject 10021_W08_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10021_W08_4_epo.fif
# Current Subject 10021_W08_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10021_W12_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10021_W12_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...   30004.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 15003 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10021_W12_2_epo.fif
# Current Subject 10021_W12_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10021_W12_3_epo.fif
# Current Subject 10021_W12_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10021_W12_4_epo.fif
# Current Subject 10021_W12_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10021_W20_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10021_W20_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  110020.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 55011 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10021_W20_2_epo.fif
# Current Subject 10021_W20_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10021_W20_3_epo.fif
# Current Subject 10021_W20_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10021_W20_4_epo.fif
# Current Subject 10021_W20_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10022_W00_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10022_W00_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  190036.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 95019 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10022_W00_2_epo.fif
# Current Subject 10022_W00_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10022_W00_3_epo.fif
# Current Subject 10022_W00_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10022_W00_4_epo.fif
# Current Subject 10022_W00_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10022_W08_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10022_W08_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  340066.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 170034 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10022_W08_2_epo.fif
# Current Subject 10022_W08_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10022_W08_3_epo.fif
# Current Subject 10022_W08_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10022_W08_4_epo.fif
# Current Subject 10022_W08_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10022_W12_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10022_W12_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  200038.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 100020 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10022_W12_2_epo.fif
# Current Subject 10022_W12_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10022_W12_3_epo.fif
# Current Subject 10022_W12_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10022_W12_4_epo.fif
# Current Subject 10022_W12_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10022_W20_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10022_W20_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  370072.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 185037 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10022_W20_2_epo.fif
# Current Subject 10022_W20_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10022_W20_3_epo.fif
# Current Subject 10022_W20_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10022_W20_4_epo.fif
# Current Subject 10022_W20_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10023_W00_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10023_W00_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  130024.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 65013 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10023_W00_2_epo.fif
# Current Subject 10023_W00_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10023_W00_3_epo.fif
# Current Subject 10023_W00_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10023_W00_4_epo.fif
# Current Subject 10023_W00_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10023_W08_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10023_W08_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  230044.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 115023 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10023_W08_2_epo.fif
# Current Subject 10023_W08_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10023_W08_3_epo.fif
# Current Subject 10023_W08_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10023_W08_4_epo.fif
# Current Subject 10023_W08_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10023_W12_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10023_W12_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  130024.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 65013 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10023_W12_2_epo.fif
# Current Subject 10023_W12_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10023_W12_3_epo.fif
# Current Subject 10023_W12_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10023_W12_4_epo.fif
# Current Subject 10023_W12_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10023_W20_epo.fif
# Current Subject 10023_W20 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10023_W20_2_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10023_W20_2_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...   20002.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 10002 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10023_W20_3_epo.fif
# Current Subject 10023_W20_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10023_W20_4_epo.fif
# Current Subject 10023_W20_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10024_W00_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10024_W00_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  250048.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 125025 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10024_W00_2_epo.fif
# Current Subject 10024_W00_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10024_W00_3_epo.fif
# Current Subject 10024_W00_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10024_W00_4_epo.fif
# Current Subject 10024_W00_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10024_W08_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10024_W08_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  390076.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 195039 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10024_W08_2_epo.fif
# Current Subject 10024_W08_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10024_W08_3_epo.fif
# Current Subject 10024_W08_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10024_W08_4_epo.fif
# Current Subject 10024_W08_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10024_W12_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10024_W12_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...   70012.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 35007 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10024_W12_2_epo.fif
# Current Subject 10024_W12_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10024_W12_3_epo.fif
# ...
# Current Subject 10046_W20_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10048_W00_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10048_W00_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  360070.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 180036 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10048_W00_2_epo.fif
# Current Subject 10048_W00_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10048_W00_3_epo.fif
# Current Subject 10048_W00_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10048_W00_4_epo.fif
# Current Subject 10048_W00_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10048_W08_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10048_W08_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  430084.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 215043 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10048_W08_2_epo.fif
# Current Subject 10048_W08_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10048_W08_3_epo.fif
# Current Subject 10048_W08_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10048_W08_4_epo.fif
# Current Subject 10048_W08_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10048_W12_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10048_W12_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  240046.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 120024 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10048_W12_2_epo.fif
# Current Subject 10048_W12_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10048_W12_3_epo.fif
# Current Subject 10048_W12_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10048_W12_4_epo.fif
# Current Subject 10048_W12_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10048_W20_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10048_W20_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  390076.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 195039 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10048_W20_2_epo.fif
# Current Subject 10048_W20_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10048_W20_3_epo.fif
# Current Subject 10048_W20_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10048_W20_4_epo.fif
# Current Subject 10048_W20_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10054_W00_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10054_W00_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  350068.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 175035 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10054_W00_2_epo.fif
# Current Subject 10054_W00_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10054_W00_3_epo.fif
# Current Subject 10054_W00_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10054_W00_4_epo.fif
# Current Subject 10054_W00_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10054_W08_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10054_W08_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...   30004.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 15003 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10054_W08_2_epo.fif
# Current Subject 10054_W08_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10054_W08_3_epo.fif
# Current Subject 10054_W08_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10054_W08_4_epo.fif
# Current Subject 10054_W08_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10054_W12_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10054_W12_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...   20002.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 10002 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10054_W12_2_epo.fif
# Current Subject 10054_W12_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10054_W12_3_epo.fif
# Current Subject 10054_W12_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10054_W12_4_epo.fif
# Current Subject 10054_W12_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10054_W20_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10054_W20_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  190036.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 95019 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10054_W20_2_epo.fif
# Current Subject 10054_W20_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10054_W20_3_epo.fif
# Current Subject 10054_W20_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10054_W20_4_epo.fif
# Current Subject 10054_W20_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10056_W00_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10056_W00_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  140026.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 70014 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10056_W00_2_epo.fif
# Current Subject 10056_W00_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10056_W00_3_epo.fif
# Current Subject 10056_W00_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10056_W00_4_epo.fif
# Current Subject 10056_W00_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10056_W08_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10056_W08_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...   40006.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 20004 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10056_W08_2_epo.fif
# Current Subject 10056_W08_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10056_W08_3_epo.fif
# Current Subject 10056_W08_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10056_W08_4_epo.fif
# Current Subject 10056_W08_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10056_W12_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10056_W12_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  120022.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 60012 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10056_W12_2_epo.fif
# Current Subject 10056_W12_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10056_W12_3_epo.fif
# Current Subject 10056_W12_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10056_W12_4_epo.fif
# Current Subject 10056_W12_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10056_W20_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10056_W20_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...   50008.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 25005 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10056_W20_2_epo.fif
# Current Subject 10056_W20_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10056_W20_3_epo.fif
# Current Subject 10056_W20_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10056_W20_4_epo.fif
# Current Subject 10056_W20_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10057_W00_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10057_W00_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...   50008.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 25005 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10057_W00_2_epo.fif
# Current Subject 10057_W00_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10057_W00_3_epo.fif
# Current Subject 10057_W00_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10057_W00_4_epo.fif
# Current Subject 10057_W00_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10057_W08_epo.fif
# Current Subject 10057_W08 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10057_W08_2_epo.fif
# Current Subject 10057_W08_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10057_W08_3_epo.fif
# Current Subject 10057_W08_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10057_W08_4_epo.fif
# Current Subject 10057_W08_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10057_W12_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10057_W12_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...   90016.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 45009 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10057_W12_2_epo.fif
# Current Subject 10057_W12_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10057_W12_3_epo.fif
# Current Subject 10057_W12_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10057_W12_4_epo.fif
# Current Subject 10057_W12_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10057_W20_epo.fif
# Current Subject 10057_W20 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10057_W20_2_epo.fif
# Current Subject 10057_W20_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10057_W20_3_epo.fif
# Current Subject 10057_W20_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10057_W20_4_epo.fif
# Current Subject 10057_W20_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10058_W00_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10058_W00_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  120022.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 60012 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10058_W00_2_epo.fif
# Current Subject 10058_W00_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10058_W00_3_epo.fif
# Current Subject 10058_W00_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10058_W00_4_epo.fif
# Current Subject 10058_W00_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10058_W08_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10058_W08_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  120022.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 60012 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10058_W08_2_epo.fif
# Current Subject 10058_W08_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10058_W08_3_epo.fif
# Current Subject 10058_W08_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10058_W08_4_epo.fif
# Current Subject 10058_W08_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10058_W12_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10058_W12_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  170032.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 85017 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10058_W12_2_epo.fif
# Current Subject 10058_W12_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10058_W12_3_epo.fif
# Current Subject 10058_W12_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10058_W12_4_epo.fif
# Current Subject 10058_W12_4 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10058_W20_epo.fif
# Reading I:\CBD_ASD_EEG\02_Epoch_EEG\Concatenated_10_Check\10058_W20_epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...  310060.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# 500.0
# Loading data for 1 events and 155031 original time points ...
# Effective window size : 2.048 (s)
# (1, 19, 102)
# (19, 102)
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10058_W20_2_epo.fif
# Current Subject 10058_W20_2 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10058_W20_3_epo.fif
# Current Subject 10058_W20_3 does not exist
# I:/CBD_ASD_EEG/02_Epoch_EEG/Concatenated_10_Check\10058_W20_4_epo.fif
# Current Subject 10058_W20_4 does not exist
